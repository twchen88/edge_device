# %%
# import everything

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# load the data

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# [60000, 28, 28], [10000, 28, 28], [60000, ], [10000, ]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 17s 2us/step

# %%
# plot the figures to be sure the dataset is loading correctly

plt.figure()
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(x_train[i])
plt.savefig("should_be_digits_please")

# %%
img = np.array(x_train[0])
print(img.shape)
# Out:
# (28, 28)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5491325302871829263
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4362010624
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7500485964928726534
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
# define model

dim = [(28 * 28,), 512, 512, 10]
#input, first layer, second layer,output

def makeModel(dim):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=dim[0]))
    model.add(keras.layers.Dense(dim[1], activation="relu"))
    model.add(keras.layers.Dense(dim[2], activation="relu"))
    model.add(keras.layers.Dense(dim[3], activation="softmax"))
    return model

model = makeModel(dim)
print(model.output_shape) # should be 10
# Out:
# (None, 10)

# %%
# compiling

optimizerMethod = "adam"
lossFunction = "categorical_crossentropy"
metricsLst = ["accuracy"]
model.compile(optimizer=optimizerMethod, loss=lossFunction, metrics=metricsLst)

# %%
# clean and organize the data
x_train = x_train.reshape(60000, 28 * 28)/255
x_test = x_test.reshape(10000, 28 * 28)/255

nClass = 10
y_train = keras.utils.to_categorical(y_train, nClass)
y_test = keras.utils.to_categorical(y_test, nClass)

# %%
# train the model

model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=2, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 469/469 - 2s - loss: 0.2151 - accuracy: 0.9353 - val_loss: 0.1150 - val_accuracy: 0.9632
# Epoch 2/20
# 469/469 - 1s - loss: 0.0793 - accuracy: 0.9750 - val_loss: 0.0784 - val_accuracy: 0.9748
# Epoch 3/20
# 469/469 - 1s - loss: 0.0506 - accuracy: 0.9844 - val_loss: 0.0747 - val_accuracy: 0.9784
# Epoch 4/20
# 469/469 - 1s - loss: 0.0355 - accuracy: 0.9886 - val_loss: 0.0816 - val_accuracy: 0.9750
# Epoch 5/20
# 469/469 - 1s - loss: 0.0265 - accuracy: 0.9912 - val_loss: 0.0836 - val_accuracy: 0.9775
# Epoch 6/20
# 469/469 - 1s - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0741 - val_accuracy: 0.9804
# Epoch 7/20
# 469/469 - 0s - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.0963 - val_accuracy: 0.9767
# Epoch 8/20
# 469/469 - 1s - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0876 - val_accuracy: 0.9788
# Epoch 9/20
# 469/469 - 0s - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.0920 - val_accuracy: 0.9783
# Epoch 10/20
# 469/469 - 0s - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.1021 - val_accuracy: 0.9770
# Epoch 11/20
# 469/469 - 0s - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0850 - val_accuracy: 0.9807
# Epoch 12/20
# 469/469 - 1s - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0868 - val_accuracy: 0.9809
# Epoch 13/20
# 469/469 - 0s - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0862 - val_accuracy: 0.9797
# Epoch 14/20
# 469/469 - 1s - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.1072 - val_accuracy: 0.9780
# Epoch 15/20
# 469/469 - 1s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.1109 - val_accuracy: 0.9768
# Epoch 16/20
# 469/469 - 1s - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0861 - val_accuracy: 0.9821
# Epoch 17/20
# 469/469 - 0s - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.1014 - val_accuracy: 0.9812
# Epoch 18/20
# 469/469 - 0s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1096 - val_accuracy: 0.9812
# Epoch 19/20
# 469/469 - 1s - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0964 - val_accuracy: 0.9814
# Epoch 20/20
# 469/469 - 1s - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0974 - val_accuracy: 0.9824

# %%
# evaluate

results = model.evaluate(x_test, y_test, verbose=2)
print("Loss: ", results[0])
print("Accuracy: ", results[1])
# Out:
# 313/313 - 0s - loss: 0.0974 - accuracy: 0.9824
# Loss:  0.09739382565021515
# Accuracy:  0.9824000000953674

# %%
# save the model
# model = tf.keras.applications.mobilenet.MobileNet(input_shape=(1, 28 * 28, 3), weights=None)
model.save('handwritten_model')
# Out:
# INFO:tensorflow:Assets written to: handwritten_model/assets

# %%
# delete current model to try loading it in
# del model
# model = keras.models.load_model('handwritten_model', compile=True)
# print(model.input)

# %%
# load in test image and resize
import PIL

sample = PIL.Image.open("6.jpg")
dim = (28, 28)
sample.show()
print(sample.size)
sample = sample.resize(dim)
sample.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=933x929 at 0x7F1098034550>
# (933, 929)
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7F10980343C8>

# %%
# process image
predict_sample = np.array(sample)
predict_sample = predict_sample[:, :, 0]
print(predict_sample.shape)
plt.imshow(predict_sample)
predict_sample = predict_sample.reshape(1, 28 * 28)/255
predict_sample = predict_sample.astype("float32")
print(predict_sample.shape)
print(predict_sample.dtype)
# Out:
# (28, 28)
# (1, 784)
# float32

# %%
# predict
prediction = model.predict(predict_sample)
print(prediction)

classes = np.argmax(prediction, axis = 1)
print(classes)
# Out:
# [[4.4457332e-04 1.7043358e-06 5.6309982e-06 3.1021602e-05 3.8270766e-04
#   8.1547302e-01 1.7002165e-01 2.8067635e-04 1.3344269e-02 1.4654812e-05]]
# [5]
